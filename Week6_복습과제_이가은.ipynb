# %% [markdown]
# # **U-Net 모델 구현**
#
# ✅ 아래 코드는 PyTorch로 작성한 간단한 U-Net 모델입니다.
#
# ✅ 주요 목표: 작은 이미지 세트로 segmentation 학습을 테스트하기!
#
# ✅ 특징: 업샘플링(deconv/upsample 선택 가능), 입력 스케일링, Gaussian noise 추가, 배치 정규화 적용

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# --- 작은 U-Net 정의 ---
class UNetSmall(nn.Module):
    def __init__(self, upsample_mode='deconv', net_scaling=None, edge_crop=0, gaussian_noise_std=0.1):
        super().__init__()
        self.net_scaling = net_scaling
        self.edge_crop = edge_crop
        self.gaussian_noise_std = gaussian_noise_std
        self.upsample_mode = upsample_mode

         # Convolution Block: Conv -> ReLU -> Conv -> ReLU
        def conv_block(in_c, out_c):
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, 3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_c, out_c, 3, padding=1),
                nn.ReLU(inplace=True)
            )

        # 인코더 부분 목표 -> 128 까지!
        self.enc1 = conv_block(3, 64)
        self.enc2 = conv_block(64, 128)
        self.enc3 = conv_block(128, 256)
        self.enc4 = conv_block(256, 512)
        # Bottleneck
        self.center = conv_block(512, 1024)
        self.pool = nn.MaxPool2d(2)


        # 업샘플링 부분 정의 (deconv 또는 upsample+conv) 로
        if upsample_mode == 'deconv':
            def upsample_layer(in_c, out_c):
                return nn.ConvTranspose2d(in_c, out_c, 2, stride=2)
        else:
            def upsample_layer(in_c, out_c):
                return nn.Sequential(
                    nn.Upsample(scale_factor=2, mode='nearest'),
                    nn.Conv2d(in_c, out_c, 1)
                )
        # 디코더 부분
        self.up4 = upsample_layer(1024, 512)
        self.dec4 = conv_block(1024, 512) # 512 (upsampled) + 512 (skip) = 1024
        self.up3 = upsample_layer(512, 256)
        self.dec3 = conv_block(512, 256) # 256 (upsampled) + 256 (skip) = 512
        self.up2 = upsample_layer(256, 128)
        self.dec2 = conv_block(256, 128) # 128 (upsampled) + 128 (skip) = 256
        self.up1 = upsample_layer(128, 64)
        self.dec1 = conv_block(128, 64) # 64 (upsampled) + 64 (skip) = 128

        # 최종 출력: 1채널(segmentation mask)
        self.final = nn.Conv2d(64, 1, 1)

    def forward(self, x):
        if self.net_scaling:
        # 입력 스케일링
            x = F.avg_pool2d(x, self.net_scaling)
        # Gaussian noise 추가
        if self.gaussian_noise_std:
            noise = torch.randn_like(x) * self.gaussian_noise_std
            x = x + noise

        # 배치 정규화 적용
        x = F.batch_norm(x, running_mean=None, running_var=None, training=True)

        # 인코더
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        # Bottleneck
        center = self.center(self.pool(e4))

        # 디코더 + Skip Connection
        d4 = self.up4(center)
        d4 = torch.cat([d4, e4], dim=1)
        d4 = self.dec4(d4)

        d3 = self.up3(d4)
        d3 = torch.cat([d3, e3], dim=1)
        d3 = self.dec3(d3)

        d2 = self.up2(d3)
        d2 = torch.cat([d2, e2], dim=1)
        d2 = self.dec2(d2)

        d1 = self.up1(d2)
        d1 = torch.cat([d1, e1], dim=1)
        d1 = self.dec1(d1)

        out = self.final(d1)
        out = torch.sigmoid(out)
         # Crop + Pad
        if self.edge_crop > 0:
            out = out[:, :, self.edge_crop:-self.edge_crop, self.edge_crop:-self.edge_crop]
            out = F.pad(out, (self.edge_crop, self.edge_crop, self.edge_crop, self.edge_crop))
        # Upsample 다시 확대
        if self.net_scaling:
            out = F.interpolate(out, scale_factor=self.net_scaling, mode='nearest')

        return out

# %% [markdown]
# ## **학습용 데이터 생성하기**

# %%
batch_size = 32
x = torch.randn(batch_size, 3, 128, 128)  # RGB 이미지
y = (torch.rand(batch_size, 1, 128, 128) > 0.5).float()  # 랜덤 이진 마스크

dataset = TensorDataset(x, y)
loader = DataLoader(dataset, batch_size=2, shuffle=True)

# %% [markdown]
# ## **데이터 시각화**

# %%
import matplotlib.pyplot as plt
# 첫 번째 이미지를 시각화
sample_x = x[0]
sample_y = y[0]

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(sample_x.permute(1, 2, 0).numpy())
plt.title('Input Image')

plt.subplot(1, 2, 2)
plt.imshow(sample_y.squeeze().numpy(), cmap='gray')
plt.title('Ground Truth Mask')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.7816772..4.222662].

# %% [markdown]
# ## **모델 선언 및 학습**

# %%
# --- 모델 선언 및 학습 ---
model = UNetSmall(upsample_mode='deconv', net_scaling=None, edge_crop=0)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.BCELoss()

# 간단히 30 epoch만
for epoch in range(10):
    model.train()
    total_loss = 0
    for xb, yb in loader:
        pred = model(xb)
        loss = criterion(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss/len(loader):.4f}")
# Out:
# Epoch 1, Loss: 0.6932
# Epoch 2, Loss: 0.6931
# Epoch 3, Loss: 0.6930
# Epoch 4, Loss: 0.6928
# Epoch 5, Loss: 0.6924
# Epoch 6, Loss: 0.6917
# Epoch 7, Loss: 0.6907
# Epoch 8, Loss: 0.6897
# Epoch 9, Loss: 0.6881
# Epoch 10, Loss: 0.6864

# %% [markdown]
# ## **아래 주석을 풀고 U-Net 모델에 대해 간단히 설명해주세요 😀**

# %% [markdown]
# [답변]
#
#
# ---
# U-Net은 encoder–decoder 구조를 기반으로 한 이미지 분할 모델이다. 인코더에서는 convolution과 pooling을 통해 점차 공간 해상도를 줄이며 특징을 추출하고, 디코더에서는 upsampling을 통해 해상도를 복원하면서 분할 결과를 생성한다. 이때 인코더의 각 단계에서 추출된 feature를 디코더에 skip connection으로 전달하여, 위치 정보와 경계 정보를 보존함으로써 보다 정밀한 segmentation이 가능하도록 한다.

# %% [markdown]
# ## **아래 주석을 풀고 DeepLabv1, v2, v3. v3+  모델에 대해 각각 간단히 설명해주세요 🐶**

# %% [markdown]
# [답변]
#
#
# ---
#
# [DeepLab v1]
# Dilated convolution을 활용하여 feature map의 해상도를 유지하면서 더 넓은 receptive field를 확보한 모델이다. 마지막 단계에서는 bilinear upsampling을 사용해 출력 크기를 복원한다.
#
# [DeepLab v2]
# ASPP(Atrous Spatial Pyramid Pooling)를 도입하여 서로 다른 dilation rate를 가진 여러 dilated convolution을 병렬로 적용하고, 이를 결합함으로써 다양한 스케일의 정보를 효과적으로 반영한다.
#
# [DeepLab v3]
# ASPP 구조를 더욱 강화하여 인코더 단계에서 다양한 스케일의 feature를 정교하게 추출한다. 또한 skip connection을 통해 디코더로 정보를 전달하여 segmentation 성능을 향상시킨다.
#
# [DeepLab v3+]
# Xception 기반 인코더를 사용하고 depthwise separable convolution을 적용하여 연산 효율과 성능을 동시에 개선한 모델이다. 또한 encoder–decoder 구조와 skip connection을 활용해 경계 정보를 보다 정밀하게 복원한다.
